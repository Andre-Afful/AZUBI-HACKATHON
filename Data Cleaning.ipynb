# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.model_selection import train_test_split
# we encode because dataset contains other datatypes other than numerical values
from sklearn.preprocessing import LabelBinarizer, StandardScaler

#from keras.models import Sequential
#from keras.layers import Dense, Embedding, LSTM, GRU
#from keras.layers.embeddings import Embedding
# %matplotlib inline

# %%
stats = pd.read_csv(r"C:\Users\ROOOT2\OneDrive\AZUBI\Classification\Seasons_Stats.csv")

# %%
stats_clean = stats.drop(['blanl', 'blank2', 'Tm'], axis=1)

# %%
stats_clean.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age     G  GS  MP  PER    TS%  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  63.0 NaN NaN  NaN  0.368
# 1           1  1950.0     Cliff Barker   SG  29.0  49.0 NaN NaN  NaN  0.435
# 2           2  1950.0    Leo Barnhorst   SF  25.0  67.0 NaN NaN  NaN  0.394
# 3           3  1950.0       Ed Bartels    F  24.0  15.0 NaN NaN  NaN  0.312
# 4           4  1950.0       Ed Bartels    F  24.0  13.0 NaN NaN  NaN  0.308
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 50 columns]

# %%
players = pd.read_csv(r"C:\Users\ROOOT2\OneDrive\AZUBI\Classification\Players.csv")
players.head(10)
# Out:
#    Unnamed: 0           Player  height  weight  \
# 0           0  Curly Armstrong   180.0    77.0
# 1           1     Cliff Barker   188.0    83.0
# 2           2    Leo Barnhorst   193.0    86.0
# 3           3       Ed Bartels   196.0    88.0
# 4           4      Ralph Beard   178.0    79.0
# 5           5       Gene Berce   180.0    79.0
# 6           6    Charlie Black   196.0    90.0
# 7           7      Nelson Bobb   183.0    77.0
# 8           8  Jake Bornheimer   196.0    90.0
# 9           9     Vince Boryla   196.0    95.0
#
#                            collage    born     birth_city   birth_state
# 0               Indiana University  1918.0            NaN           NaN
# 1           University of Kentucky  1921.0       Yorktown       Indiana
# 2         University of Notre Dame  1924.0            NaN           NaN
# 3  North Carolina State University  1925.0            NaN           NaN
# 4           University of Kentucky  1927.0    Hardinsburg      Kentucky
# 5             Marquette University  1926.0            NaN           NaN
# 6             University of Kansas  1921.0           Arco         Idaho
# 7                Temple University  1924.0   Philadelphia  Pennsylvania
# 8               Muhlenberg College  1927.0  New Brunswick    New Jersey
# 9             University of Denver  1927.0   East Chicago       Indiana

# %%
data = pd.merge(stats_clean, players[['Player', 'height', 'weight']], left_on='Player', right_on='Player', right_index=False,
      how='left', sort=False).fillna(value=0)
data = data[~(data['Pos']==0) & (data['MP'] > 400)]
data.reset_index(inplace=True, drop=True)
data['Player'] = data['Player'].str.replace('*','')

totals = ['PER', 'OWS', 'DWS', 'WS', 'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA',
         'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']

for col in totals:
    data[col] = 36 * data[col] / data['MP']

# %%
#NULL value checker
data.isnull().sum()
# Out:
# Unnamed: 0    0
# Year          0
# Player        0
# Pos           0
# Age           0
# G             0
# GS            0
# MP            0
# PER           0
# TS%           0
# 3PAr          0
# FTr           0
# ORB%          0
# DRB%          0
# TRB%          0
# AST%          0
# STL%          0
# BLK%          0
# TOV%          0
# USG%          0
# OWS           0
# DWS           0
# WS            0
# WS/48         0
# OBPM          0
# DBPM          0
# BPM           0
# VORP          0
# FG            0
# FGA           0
# FG%           0
# 3P            0
# 3PA           0
# 3P%           0
# 2P            0
# 2PA           0
# 2P%           0
# eFG%          0
# FT            0
# FTA           0
# FT%           0
# ORB           0
# DRB           0
# TRB           0
# AST           0
# STL           0
# BLK           0
# TOV           0
# PF            0
# PTS           0
# height        0
# weight        0
# dtype: int64
